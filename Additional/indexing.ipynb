# %% [markdown]
# ## 퀴즈

# %% [markdown]
# ### 🔢 인덱싱 문제
# #### 문제 1

# %%
word = "Python"
# 예상 결과: h
# 예상 결과: n

# 여기에 코드 작성

print(word[3]) #h
print(word[5]) #n

# %% [markdown]
# #### 문제 2

# %%
numbers = [10, 20, 30, 40, 50]
# 예상 결과: 30
# 예상 결과: 10

# 여기에 코드 작성

print(numbers[2]) #30
print(numbers[0]) #10

# %% [markdown]
# #### 문제 3

# %%
text = "Python"
# 예상 결과: Pyt
# 예상 결과: thon


# 여기에 코드 작성
print(text[:3]) #Pyt
print(text[2:]) #thon

# %% [markdown]
# #### 문제 4

# %%
data = [10, 20, 30, 40, 50]
# 예상 결과: [20, 30, 40]
# 예상 결과: [50, 40, 30, 20, 10]

# 여기에 코드 작성
print(data[1:4]) # [20, 30, 40]
print(data[::-1]) # [50, 40, 30, 20, 10]
